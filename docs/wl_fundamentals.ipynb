# %%
from wolframclient.evaluation import WolframLanguageSession
from wolframclient.language import expression, wl, wlexpr

session = WolframLanguageSession()
basePath = "C:\\Program Files\\Wolfram Research\\Wolfram Engine\\12.1\\AddOns\\Applications\\"

# %%
session.evaluate(wl.FullForm("{a,b,c}"))
# Out:
# FullForm['{a,b,c}']

# %%
session.evaluate("FullForm[a+b+c]")
# Out:
# FullForm[Plus[Global`a, Global`b, Global`c]]

# %%
session.evaluate("?Apply").args[0]
# Out:
# InformationData[{'ObjectType': 'Symbol', 'Usage': '\uf7c1\uf7c9\uf7c8RowBox[{StyleBox["f", "TI"], "@@", StyleBox["expr", "TI"]}]\uf7c0 or \uf7c1\uf7c9\uf7c8RowBox[{"Apply", "[", RowBox[{StyleBox["f", "TI"], ",", StyleBox["expr", "TI"]}], "]"}]\uf7c0 replaces the head of \uf7c1\uf7c9\uf7c8StyleBox["expr", "TI"]\uf7c0 by \uf7c1\uf7c9\uf7c8StyleBox["f", "TI"]\uf7c0. \n\uf7c1\uf7c9\uf7c8RowBox[{StyleBox["f", "TI"], "@@@", StyleBox["expr", "TI"]}]\uf7c0 or \uf7c1\uf7c9\uf7c8RowBox[{"Apply", "[", RowBox[{StyleBox["f", "TI"], ",", StyleBox["expr", "TI"], ",", RowBox[{"{", "1", "}"}]}], "]"}]\uf7c0 replaces heads at level 1 of \uf7c1\uf7c9\uf7c8StyleBox["expr", "TI"]\uf7c0 by \uf7c1\uf7c9\uf7c8StyleBox["f", "TI"]\uf7c0.\n\uf7c1\uf7c9\uf7c8RowBox[{"Apply", "[", RowBox[{StyleBox["f", "TI"], ",", StyleBox["expr", "TI"], ",", StyleBox["levelspec", "TI"]}], "]"}]\uf7c0 replaces heads in parts of \uf7c1\uf7c9\uf7c8StyleBox["expr", "TI"]\uf7c0 specified by \uf7c1\uf7c9\uf7c8StyleBox["levelspec", "TI"]\uf7c0. \n\uf7c1\uf7c9\uf7c8RowBox[{"Apply", "[", StyleBox["f", "TI"], "]"}]\uf7c0 represents an operator form of Apply that can be applied to an expression.', 'Documentation': None, 'OwnValues': None, 'UpValues': None, 'DownValues': None, 'SubValues': None, 'DefaultValues': None, 'NValues': None, 'FormatValues': None, 'Options': (Rule[Heads, False],), 'Attributes': (Protected,), 'FullName': 'System`Apply'}, False]

# %%
session.evaluate("FullForm[a+b+c]")
# Out:
# FullForm[Plus[Global`a, Global`b, Global`c]]

# %%
session.evaluate("Plus[a,b,c]")
# Out:
# Plus[Global`a, Global`b, Global`c]

# %%
session.evaluate("FullForm[{a,b,c}]")
# Out:
# FullForm[(Global`a, Global`b, Global`c)]

# %%
session.evaluate("List[a,b,c]")
# Out:
# (Global`a, Global`b, Global`c)

# %%
session.evaluate("Apply[Plus,{a,b,c}]")
# Out:
# Plus[Global`a, Global`b, Global`c]

# %%
session.evaluate("Trace[Apply[Plus,{a,b,c}]]")
# Out:
# ()

# %%
session.evaluate("Apply[List,a+b+c]")
# Out:
# (Global`a, Global`b, Global`c)

# %%
session.evaluate("Apply[List,1+2+3]")
# Out:
# 6

# %% [markdown]
# ### Non-atomic expressions

# %%
session.evaluate("Part[{a,7,c},1]")
# Out:
# Global`a

# %%
# Part 0 is the head of the expression
session.evaluate("Part[{a,7,c},0]")
# Out:
# List
